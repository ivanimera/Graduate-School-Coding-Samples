# %%
import mrjob

# %%
mrjob(help)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-0c785d53851c> in <module>()
# ----> 1 mrjob(help)
#
# TypeError: 'module' object is not callable

# %%
help(mrjob)
# Out:
# Help on package mrjob:
#
# NAME
#     mrjob
#
# DESCRIPTION
#     Write and run Hadoop Streaming jobs on
#     Amazon Elastic MapReduce / Google Dataproc / your own Hadoop cluster.
#
# PACKAGE CONTENTS
#     aws
#     bin
#     cat
#     cloud
#     cmd
#     compat
#     conf
#     dataproc
#     emr
#     examples (package)
#     fs (package)
#     hadoop
#     iam
#     inline
#     job
#     launch
#     local
#     logs (package)
#     options
#     parse
#     pool
#     protocol
#     py2
#     retry
#     runner
#     setup
#     sim
#     step
#     tools (package)
#     util
#
# VERSION
#     0.6.1
#
# AUTHOR
#     David Marin <dm@davidmarin.org>
#
# CREDITS
# ...

# %%
from mrjob.job import MRJob
imoprt re

class Max(MRJob):
    def mapper(self, -, line):
        yield ("num", line)
    
    def reducer(self, num, numbers):
        max_num = 0
        for items in numbers:
            max_num = max(item, max_num)
            
        yield("max", max_num)
if __name__=='__main__'

# %%
import pandas

# %%
csvs = pandas.read_csv("c://Users//ivani//OneDrive//Pictures//Data Mining Resources//Discrete Math for Data Science//Email attachments//Documents//Desktop//imera.csv")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-71-de41351ae4a5> in <module>()
# ----> 1 csvs = pandas.read_csv("c://Users//ivani//OneDrive//Pictures//Data Mining Resources//Discrete Math for Data Science//Email attachments//Documents//Desktop//imera.csv")
#
# ...

# %%
csvs
# Out:
#            3723753600.0  2274.09741211  3.106096208
# 0          3.723754e+09    2274.092041     3.106096
# 1          3.723754e+09    2274.090332     3.106096
# 2          3.723754e+09    2274.091797     3.106096
# 3          3.723754e+09    2274.095215     3.106096
# 4          3.723754e+09    2274.090088     3.106096
# 5          3.723754e+09    2274.089111     3.106096
# 6          3.723754e+09    2274.094727     3.106096
# 7          3.723754e+09    2274.084229     3.106096
# 8          3.723754e+09    2274.089111     3.106096
# 9          3.723754e+09    2274.093262     3.106096
# 10         3.723754e+09    2274.089600     3.106096
# 11         3.723754e+09    2274.089844     3.106095
# 12         3.723754e+09    2274.093506     3.106095
# 13         3.723754e+09    2274.096680     3.106095
# 14         3.723754e+09    2274.091309     3.106095
# 15         3.723754e+09    2274.090088     3.106095
# 16         3.723754e+09    2274.091553     3.106095
# ...

# %%
len(csvs)
# Out:
# 100465670

# %%
type(csvs)
# Out:
# pandas.core.frame.DataFrame

# %%
csvs.dtype(csvs[1:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-02bcf8c5e34a> in <module>()
# ----> 1 csvs.dtype(csvs[1:])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
list(csvs[:].unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-b5229a80f37b> in <module>()
# ----> 1 list(csvs[:].unique())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
import numpy

# %%
numpy.where(pandas.isnull(csvs))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
numpy.where(csvs.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
pandas.DataFrame.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-05787bef5ee4> in <module>()
# ----> 1 csvs.isin("")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in isin(self, values)
#    5472                                 "allowed to be passed to DataFrame.isin(), "
#    5473                                 "you passed a "
# -> 5474                                 "{0!r}".format(type(values).__name__))
#    5475             return DataFrame(
#    5476                 algorithms.isin(self.values.ravel(),
#
# TypeError: only list-like or dict-like objects are allowed to be passed to DataFrame.isin(), you passed a 'str'

# %%
sortcsvs = sorted(csvs.iloc[:,0])

# %%
sortcsvs
# Out:
# [3723753600.0500002,
#  3723753600.0999999,
#  3723753600.1500001,
#  3723753600.1999998,
#  3723753600.25,
#  3723753600.3000002,
#  3723753600.3499999,
#  3723753600.4000001,
#  3723753600.4499998,
#  3723753600.5,
#  3723753600.5500002,
#  3723753600.5999999,
#  3723753600.6500001,
#  3723753600.6999998,
#  3723753600.75,
#  3723753600.8000002,
#  3723753600.8499999,
#  3723753600.9000001,
#  3723753600.9499998,
#  3723753601.0,
#  3723753601.0500002,
#  3723753601.0999999,
#  3723753601.1500001,
#  3723753601.1999998,
#  3723753601.25,
#  3723753601.3000002,
#  3723753601.3499999,
#  3723753601.4000001,
#  3723753601.4499998,
#  3723753601.5,
#  3723753601.5500002,
#  3723753601.5999999,
#  3723753601.6500001,
#  3723753601.6999998,
#  3723753601.75,
#  3723753601.8000002,
#  3723753601.8499999,
#  3723753601.9000001,
#  3723753601.9499998,
#  3723753602.0,
#  3723753602.0500002,
#  3723753602.0999999,
#  3723753602.1500001,
#  3723753602.1999998,
#  3723753602.25,
# ...

# %%
len(sortcsvs)/4
# Out:
# 25116417.5

# %%
len(sortcsvs)/4
# Out:
# 25116417.5

# %%
(sortcsvs[25116417]+ sortcsvs[25116418])/2
# Out:
# 3725009459.8249998

# %%
sortcsvs[int(25116417.5*2)]
# Out:
# 3726328843.5

# %%
csvs.iloc[0:10,0]
# Out:
# 0    3.723754e+09
# 1    3.723754e+09
# 2    3.723754e+09
# 3    3.723754e+09
# 4    3.723754e+09
# 5    3.723754e+09
# 6    3.723754e+09
# 7    3.723754e+09
# 8    3.723754e+09
# 9    3.723754e+09
# Name: 3723753600.0, dtype: float64

# %%
print(list(csvs.iloc[0:10,0]))
# Out:
# [3723753600.0500002, 3723753600.0999999, 3723753600.1500001, 3723753600.1999998, 3723753600.25, 3723753600.3000002, 3723753600.3499999, 3723753600.4000001, 3723753600.4499998, 3723753600.5]

# %%
sortcsvs2 = sorted(csvs.iloc[:,1])

# %%
sortcsvs2
# Out:
# [2273.2722168,
#  2273.2741699200001,
#  2273.2744140599998,
#  2273.27612305,
#  2273.2763671900002,
#  2273.2766113299999,
#  2273.2766113299999,
#  2273.2766113299999,
#  2273.2768554700001,
#  2273.27734375,
#  2273.2775878900002,
#  2273.2775878900002,
#  2273.2775878900002,
#  2273.27856445,
#  2273.27856445,
#  2273.27856445,
#  2273.27856445,
#  2273.27856445,
#  2273.2788085900002,
#  2273.2790527299999,
#  2273.2792968799999,
#  2273.2792968799999,
#  2273.2792968799999,
#  2273.2792968799999,
#  2273.2797851599998,
#  2273.2797851599998,
#  2273.2797851599998,
#  2273.2797851599998,
#  2273.2800293,
#  2273.2800293,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2802734400002,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
#  2273.2805175799999,
# ...

# %%
len(sortcsvs2)/4
# Out:
# 25116417.5

# %%
sortcsvs2[25116417],sortcsvs2[25116418]
# Out:
# (2275.4511718799999, 2275.4511718799999)

# %%
25116417.5*3
# Out:
# 75349252.5

# %%
type(i for i in sortcsvs2)
# Out:
# generator

# %%
lstcsv2 =[]
for i in sortcsvs2:
    lstcsv2.append(type(i))
